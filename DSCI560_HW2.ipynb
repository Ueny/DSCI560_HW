# %% [markdown]
# ### Note: in order to make sure the scripts go well. Please have a python version above 3 and install a package matplotlib

# %% [markdown]
# ## 1. Run the script random_numbers.py

# %% [markdown]
# ### We use a random package to generate uniform numbers repeatedly, and the range of the random number is from 0 to 100. The process will be repeated for 1000 times. We are able to have a visualization about the distribution of the 1000 random numbers. The X axis represents the number ID from 1 to 1000, and the y axis represents number values.

# %%
# %run random_numbers.py

# %% [markdown]
# ### Read the result (1000 random numbers) from the generated file

# %%
with open('random_numbers.csv', 'r')as f:
    randNums = list(map(float, f.readlines()))

# %% [markdown]
# ### Show a small sample of the data (top 10 of the 1000 numbers)

# %%
randNums[:10]
# Out:
# [89.07636672219832,
#  66.91754352775791,
#  11.393112882628865,
#  45.1788412084184,
#  71.15334511483996,
#  39.58255098470925,
#  87.78465163773707,
#  23.793973808860137,
#  75.6067611202179,
#  28.420000997539717]

# %% [markdown]
# ## 2. Run the script update_numbers.py

# %% [markdown]
# ### Based on previous 1000 random numbers, we implement a function y = 3x + 6 on each one, so we have new numbers from 6 to 306. We are also able to have a visualization about the distribution of the 1000 numbers. The X axis represents the number ID from 1 to 1000, and the y axis represents new values.

# %%
# %run update_numbers.py

# %% [markdown]
# ### Read the result (1000 numbers after the function) from the generated file

# %%
with open('update_numbers.csv', 'r')as f:
    updateNums = list(map(float, f.readlines()))

# %% [markdown]
# ### Show a small sample of the data (top 10 of the 1000 numbers)

# %%
updateNums[:10]
# Out:
# [273.22910016659495,
#  206.75263058327374,
#  40.179338647886595,
#  141.5365236252552,
#  219.4600353445199,
#  124.74765295412774,
#  269.3539549132112,
#  77.38192142658042,
#  232.8202833606537,
#  91.26000299261915]

# %% [markdown]
# ## 3. Run the script visualization.py

# %% [markdown]
# ### Based on the previous data from step 1 and 2, we are going to have a data visualization with random numbers (step 1) as X and after-function numbers (step 2) as Y. The scattered plot is as follows.

# %%
# %run visualization.py
